# %% [markdown]
# # RetailPulse - Week 1 Checkpoint
#
# ## AI-Powered Customer Analytics & Demand Forecasting Platform
#
# ### Week 1 Objectives
# - Exploratory Data Analysis (EDA)
# - Data Cleaning & Feature Engineering
# - Customer Segmentation
# - Time-Series Data Preparation
# - Prophet Forecasting
# - LSTM Forecasting

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Week 1 Deliverables

# %%
cleaned = pd.read_csv("../data/cleaned_retail.csv")

rfm = pd.read_csv("../data/rfm_segmented.csv")

forecast = pd.read_csv("../data/forecast_results.csv")

lstm = pd.read_csv("../data/lstm_predictions.csv")

# %% [markdown]
# ## Dataset Summary

# %%
print("Cleaned Dataset Shape:")
print(cleaned.shape)

print("\nRFM Dataset Shape:")
print(rfm.shape)

print("\nForecast Dataset Shape:")
print(forecast.shape)

print("\nLSTM Predictions Shape:")
print(lstm.shape)
# Out:
# Cleaned Dataset Shape:
# (392693, 16)
#
# RFM Dataset Shape:
# (4338, 6)
#
# Forecast Dataset Shape:
# (335, 19)
#
# LSTM Predictions Shape:
# (55, 2)

# %% [markdown]
# ## Data Cleaning Summary

# %%
cleaned.head()
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1   536365     71053                  WHITE METAL LANTERN         6
# 2   536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3   536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  Price  Customer ID         Country  TotalAmount  Year  \
# 0  2010-12-01 08:26:00   2.55      17850.0  United Kingdom        15.30  2010
# 1  2010-12-01 08:26:00   3.39      17850.0  United Kingdom        20.34  2010
# 2  2010-12-01 08:26:00   2.75      17850.0  United Kingdom        22.00  2010
# 3  2010-12-01 08:26:00   3.39      17850.0  United Kingdom        20.34  2010
# 4  2010-12-01 08:26:00   3.39      17850.0  United Kingdom        20.34  2010
#
#    Month  Day    Weekday  Quarter  CustomerFrequency OrderSize
# ...

# %% [markdown]
# ## Customer Segmentation Results

# %%
rfm["Segment"].value_counts()
# Out:
# Segment
# Regular    3247
# VIP        1081
# Loyal         6
# At Risk       4
# Name: count, dtype: int64

# %%
rfm["Segment"].value_counts().plot(
    kind="bar"
)

plt.title(
    "Customer Segments"
)

plt.xlabel("Segment")

plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## Forecasting Results

# %%
forecast.head()
# Out:
#            ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0  2010-12-01  16916.270728  14082.509056  47397.718432  16916.270728
# 1  2010-12-02  16988.696639  22720.345295  55298.155646  16988.696639
# 2  2010-12-03  17061.122549  15150.989198  48652.293498  17061.122549
# 3  2010-12-05  17205.974371   5456.765501  36681.859618  17205.974371
# 4  2010-12-06  17278.400281  17527.866846  50415.614544  17278.400281
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  16916.270728    13613.664254          13613.664254          13613.664254
# 1  16988.696639    22030.968253          22030.968253          22030.968253
# 2  17061.122549    14910.764239          14910.764239          14910.764239
# 3  17205.974371     3162.368907           3162.368907           3162.368907
# 4  17278.400281    16695.041899          16695.041899          16695.041899
#
#          weekly  weekly_lower  weekly_upper        yearly  yearly_lower  \
# ...

# %%
forecast[
    ["ds","yhat"]
].tail(30)
# Out:
#              ds          yhat
# 305  2011-12-10  78109.165063
# 306  2011-12-11  47356.913283
# 307  2011-12-12  59679.835550
# 308  2011-12-13  63011.027519
# 309  2011-12-14  59096.802038
# 310  2011-12-15  65107.101586
# 311  2011-12-16  55561.321785
# 312  2011-12-17  70995.410678
# 313  2011-12-18  39135.704153
# 314  2011-12-19  50529.373812
# 315  2011-12-20  53131.971348
# 316  2011-12-21  48707.401442
# 317  2011-12-22  54437.855382
# 318  2011-12-23  44849.295095
# 319  2011-12-24  60478.361857
# 320  2011-12-25  29046.175625
# 321  2011-12-26  41088.902627
# 322  2011-12-27  44545.572386
# 323  2011-12-28  41158.469153
# 324  2011-12-29  48083.618884
# 325  2011-12-30  39816.946767
# 326  2011-12-31  56861.961564
# 327  2012-01-01  26904.411919
# 328  2012-01-02  40443.769306
# 329  2012-01-03  45381.994190
# 330  2012-01-04  43424.884911
# 331  2012-01-05  51693.504735
# 332  2012-01-06  44651.236885
# 333  2012-01-07  62772.299825
# 334  2012-01-08  33717.145805

# %%
forecast["yhat"].describe()
# Out:
# count      335.000000
# mean     30989.444184
# std      13412.600332
# min        519.014987
# 25%      22771.914454
# 50%      28420.817723
# 75%      39077.684522
# max      78109.165063
# Name: yhat, dtype: float64

# %% [markdown]
# ## LSTM Forecasting Results

# %%
lstm.head()
# Out:
#       Actual  Predicted
# 0  49089.473  27838.027
# 1  12215.510  27867.045
# 2  42962.797  28332.760
# 3  46401.137  28388.158
# 4  27655.200  28329.787

# %%
plt.figure(figsize=(12,6))

plt.plot(
    lstm["Actual"],
    label="Actual"
)

plt.plot(
    lstm["Predicted"],
    label="Predicted"
)

plt.legend()

plt.title(
    "LSTM Forecast Results"
)

plt.show()

# %% [markdown]
# # Week 1 Achievements
#
# ### Completed Tasks
#
# 1. Performed Exploratory Data Analysis (EDA) on Online Retail II dataset.
#
# 2. Cleaned missing values and removed duplicate records.
#
# 3. Created new business features:
#    - TotalAmount
#    - Revenue
#    - Order Frequency
#
# 4. Built RFM model for customer behavior analysis.
#
# 5. Segmented customers using K-Means clustering.
#
# 6. Prepared daily sales time-series dataset.
#
# 7. Built Prophet model for demand forecasting.
#
# 8. Implemented LSTM model using PyTorch.
#
# 9. Generated future sales predictions.
#
# 10. Saved trained forecasting models.
